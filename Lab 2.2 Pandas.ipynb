# %% [markdown]
# ### Introduction To Pandas Module
# Here, we are learning data analysis. Pandas is a software library written for the Python programming language that helps with data manipulation and analysis. It offers various data structures which help in the manipulation of data. <br>
# One of the data structures used is DataFrame.<br>
# DataFrame is used as a way to store data in a rectangular grid.<br>
# Similar to how data is stored in Microsoft Excel.
# ### Installation
# We can easily install this library using the terminal. Follow the steps given below to install Pandas:<br>
# Step 1: Go to the Windows PowerShell.<br>
# Step 2: We can install pandas with the help of pip easily. Head over to the directory where you want to install the pandas and fire the below command:<br>
# __pip install pandas__<br>
# This is very simple to install.

# %%
# !pip install pandas

# %% [markdown]
# ### Other way to install
# If the above steps do not work for you, here is another way to install:<br>
# Step 1: Go to your browser. Search for __python unofficial binaries__, or click <br>
# https://www.lfd.uci.edu/~gohlke/pythonlibs/<br>
# and you will be redirected to the binary page.<br>
# Step 2: To download the library, search for pandas – Ctrl + F will help you. Download pandas library based on your python version. <br>
# Step 3: After the installation, head over to the directory where you've downloaded the pandas. <br>
# Step 4: Right-click to open Windows PowerShell. Pip can help us with the installation. Just go to that location in your terminal and run the following command: <br>
# __pip install pandas__ <br>
# Complete this command by the TAB button so that the location of your folder is mentioned.

# %% [markdown]
# ### import pandas
# Once Pandas is installed, import it in your applications by adding the import keyword:<br>
# __import pandas as pd__<br>
# Now Pandas is imported and ready to use.

# %%
import pandas

# %%
students = {
    'Name': ["Daniyal Basharat", " M Abdullah", "Muhammad Abid", "Shumail Khan","Qasim Ali"],
    'Marks': [80, 72, 77, 65, 15],
    'Class':["1st Year", "2nd Year", "1st Year", "3rd Year", "2nd Year"],
    'Age': [20, 21, 19, 22, 21]
}

# %%
df = pandas.DataFrame(students)

# %%
df
# Out:
#                Name  Marks     Class  Age
# 0  Daniyal Basharat     80  1st Year   20
# 1        M Abdullah     72  2nd Year   21
# 2     Muhammad Abid     77  1st Year   19
# 3      Shumail Khan     65  3rd Year   22
# 4         Qasim Ali     15  2nd Year   21

# %% [markdown]
# ### Pandas as pd
# Pandas is usually imported under the pd alias.
# #### alias:
# In Python alias are an alternate name for referring to the same thing.<br>
# Create an alias with the as keyword while importing:<br>
# __import pandas as pd__<br>
# Now the Pandas package can be referred to as pd instead of pandas.

# %%
import pandas as pd

# %%
df = pd.DataFrame(students)

# %%
df
# Out:
#                Name  Marks     Class  Age
# 0  Daniyal Basharat     80  1st Year   20
# 1        M Abdullah     72  2nd Year   21
# 2     Muhammad Abid     77  1st Year   19
# 3      Shumail Khan     65  3rd Year   22
# 4         Qasim Ali     15  2nd Year   21

# %% [markdown]
# ### Checking Pandas Version
# The version string is stored under __version__ attribute.

# %%
pd.__version__
# Out:
# '3.0.3'

# %% [markdown]
# ## Saving to CSV and other extensions like excel

# %%
df.to_csv('pythonMonday.csv')

# %% [markdown]
# ## Remove Index and saving the csv file

# %%
df.to_csv('pythonMondayRemoveIndex.csv', index=False)

# %% [markdown]
# ## Show some rows from the Start

# %%
df.head()
# Out:
#                Name  Marks     Class  Age
# 0  Daniyal Basharat     80  1st Year   20
# 1        M Abdullah     72  2nd Year   21
# 2     Muhammad Abid     77  1st Year   19
# 3      Shumail Khan     65  3rd Year   22
# 4         Qasim Ali     15  2nd Year   21

# %% [markdown]
# ## Specify No of rows to show

# %%
df.head(3)
# Out:
#                Name  Marks     Class  Age
# 0  Daniyal Basharat     80  1st Year   20
# 1        M Abdullah     72  2nd Year   21
# 2     Muhammad Abid     77  1st Year   19

# %%
df.tail(3)
# Out:
#             Name  Marks     Class  Age
# 2  Muhammad Abid     77  1st Year   19
# 3   Shumail Khan     65  3rd Year   22
# 4      Qasim Ali     15  2nd Year   21

# %%
df.tail()
# Out:
#                Name  Marks     Class  Age
# 0  Daniyal Basharat     80  1st Year   20
# 1        M Abdullah     72  2nd Year   21
# 2     Muhammad Abid     77  1st Year   19
# 3      Shumail Khan     65  3rd Year   22
# 4         Qasim Ali     15  2nd Year   21

# %%
df.describe()
# Out:
#            Marks        Age
# count   5.000000   5.000000
# mean   61.800000  20.600000
# std    26.771253   1.140175
# min    15.000000  19.000000
# 25%    65.000000  20.000000
# 50%    72.000000  21.000000
# 75%    77.000000  21.000000
# max    80.000000  22.000000

# %% [markdown]
# # Reading csv or other files

# %%
classData= pd.read_csv("pythonMondayRemoveIndex.csv")
classData
# Out:
#                Name  Marks     Class  Age
# 0  Daniyal Basharat     80  1st Year   20
# 1        M Abdullah     72  2nd Year   21
# 2     Muhammad Abid     77  1st Year   19
# 3      Shumail Khan     65  3rd Year   22
# 4         Qasim Ali     15  2nd Year   21

# %%
classData= pd.read_csv("pythonMonday.csv")
classData
# Out:
#    Unnamed: 0              Name  Marks     Class  Age
# 0           0  Daniyal Basharat     80  1st Year   20
# 1           1        M Abdullah     72  2nd Year   21
# 2           2     Muhammad Abid     77  1st Year   19
# 3           3      Shumail Khan     65  3rd Year   22
# 4           4         Qasim Ali     15  2nd Year   21

# %%
classData.drop('Name', axis=1)
# Out:
#    Unnamed: 0  Marks     Class  Age
# 0           0     80  1st Year   20
# 1           1     72  2nd Year   21
# 2           2     77  1st Year   19
# 3           3     65  3rd Year   22
# 4           4     15  2nd Year   21

# %%
classData
# Out:
#    Unnamed: 0              Name  Marks     Class  Age
# 0           0  Daniyal Basharat     80  1st Year   20
# 1           1        M Abdullah     72  2nd Year   21
# 2           2     Muhammad Abid     77  1st Year   19
# 3           3      Shumail Khan     65  3rd Year   22
# 4           4         Qasim Ali     15  2nd Year   21

# %%
classData.drop(0, axis=0)
# Out:
#    Unnamed: 0           Name  Marks     Class  Age
# 1           1     M Abdullah     72  2nd Year   21
# 2           2  Muhammad Abid     77  1st Year   19
# 3           3   Shumail Khan     65  3rd Year   22
# 4           4      Qasim Ali     15  2nd Year   21

# %%
classData
# Out:
#    Unnamed: 0              Name  Marks     Class  Age
# 0           0  Daniyal Basharat     80  1st Year   20
# 1           1        M Abdullah     72  2nd Year   21
# 2           2     Muhammad Abid     77  1st Year   19
# 3           3      Shumail Khan     65  3rd Year   22
# 4           4         Qasim Ali     15  2nd Year   21

# %% [markdown]
# # Check the spelling

# %%
classData['Class']
# Out:
# 0    1st Year
# 1    2nd Year
# 2    1st Year
# 3    3rd Year
# 4    2nd Year
# Name: Class, dtype: str

# %% [markdown]
# # Check the trail space

# %%
classData.columns = classData.columns.str.strip().str.lower()

# %%
classData['class']
# Out:
# 0    1st Year
# 1    2nd Year
# 2    1st Year
# 3    3rd Year
# 4    2nd Year
# Name: class, dtype: str

# %% [markdown]
# # Corrected Spelling

# %%
classData['name']
# Out:
# 0    Daniyal Basharat
# 1          M Abdullah
# 2       Muhammad Abid
# 3        Shumail Khan
# 4           Qasim Ali
# Name: name, dtype: str

# %% [markdown]
# # Check the head space

# %%
classData['name']
# Out:
# 0    Daniyal Basharat
# 1          M Abdullah
# 2       Muhammad Abid
# 3        Shumail Khan
# 4           Qasim Ali
# Name: name, dtype: str

# %%
type(classData['name'])
# Out:
# pandas.Series

# %%
classData['age']
# Out:
# 0    20
# 1    21
# 2    19
# 3    22
# 4    21
# Name: age, dtype: int64

# %% [markdown]
# classData['gpa'][0]

# %%
classData['age'][0]
# Out:
# np.int64(20)

# %%
classData['age'][0]=90
# Out:
# C:\Users\engin\AppData\Local\Temp\ipykernel_20476\3711599208.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   classData['age'][0]=90

# %%
classData
# Out:
#    unnamed: 0              name  marks     class  age
# 0           0  Daniyal Basharat     80  1st Year   20
# 1           1        M Abdullah     72  2nd Year   21
# 2           2     Muhammad Abid     77  1st Year   19
# 3           3      Shumail Khan     65  3rd Year   22
# 4           4         Qasim Ali     15  2nd Year   21

# %%
classData['age'][4]
# Out:
# np.int64(21)

# %%
classData['age'][4]=5
# Out:
# C:\Users\engin\AppData\Local\Temp\ipykernel_20476\2197085196.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   classData['age'][4]=5

# %%
classData["name"][4]
# Out:
# 'Qasim Ali'

# %% [markdown]
# # Rename the column name

# %%
classData.rename(columns={'age': 'AGE'})
# Out:
#    unnamed: 0              name  marks     class  AGE
# 0           0  Daniyal Basharat     80  1st Year   20
# 1           1        M Abdullah     72  2nd Year   21
# 2           2     Muhammad Abid     77  1st Year   19
# 3           3      Shumail Khan     65  3rd Year   22
# 4           4         Qasim Ali     15  2nd Year   21

# %% [markdown]
# ## Create Labels
# With the index argument, you can name your own labels.

# %%
classData.index = ["First","Second", "Third", "Fourth", "Fifth"]
classData
# Out:
#         unnamed: 0              name  marks     class  age
# First            0  Daniyal Basharat     80  1st Year   20
# Second           1        M Abdullah     72  2nd Year   21
# Third            2     Muhammad Abid     77  1st Year   19
# Fourth           3      Shumail Khan     65  3rd Year   22
# Fifth            4         Qasim Ali     15  2nd Year   21

# %% [markdown]
# # Asignment

# %%
classdata = classData.drop('unnamed: 0', axis=1)
classData
# Out:
#         unnamed: 0              name  marks     class  age
# First            0  Daniyal Basharat     80  1st Year   20
# Second           1        M Abdullah     72  2nd Year   21
# Third            2     Muhammad Abid     77  1st Year   19
# Fourth           3      Shumail Khan     65  3rd Year   22
# Fifth            4         Qasim Ali     15  2nd Year   21

# %% [markdown]
# # Inplace

# %%
classData.drop('unnamed: 0', axis=1, inplace = True)
classData
# Out:
#                     name  marks     class  age
# First   Daniyal Basharat     80  1st Year   20
# Second        M Abdullah     72  2nd Year   21
# Third      Muhammad Abid     77  1st Year   19
# Fourth      Shumail Khan     65  3rd Year   22
# Fifth          Qasim Ali     15  2nd Year   21

# %% [markdown]
# # Accessing the value in Dataframe

# %%
classData["name"]
# Out:
# First     Daniyal Basharat
# Second          M Abdullah
# Third        Muhammad Abid
# Fourth        Shumail Khan
# Fifth            Qasim Ali
# Name: name, dtype: str

# %%
classData["name"]["Fifth"]
# Out:
# 'Qasim Ali'

# %% [markdown]
# ## Pandas
# Pandas is an open source data analysis library written in Python.<br>
# It uses the power and speed of numpy to make data analysis and preprocessing easy for data scientists.<br>
# __Pandas__ is used to analyze data.<br>
# Python data analysis using pandas is a great start to Exploratory Data Analysis (EDA) for a data scientist.

# %% [markdown]
# ## Pandas Data Structure
# Panda has two types of Data Structure:<br>
#     a) Series<br>
#     b) Dataframe
# ### Series
# It is a one dimentional array with indexes. It stores a single column or row of data in a Dataframe.<br>
# It is a one dimensional array capable of holding any type of data.
# ### Dataframe
# It is a tabular spreadsheet like structure representing rows each of which contains one or more columns.<br>
# It is a multi dimensional array capable of holding any type of data.<br>
# __Series__ is like a column, a __DataFrame__ is the whole table.

# %%
classData['age']
# Out:
# First     20
# Second    21
# Third     19
# Fourth    22
# Fifth     21
# Name: age, dtype: int64

# %%
type(classData['age'])
# Out:
# pandas.Series

# %%
classData
# Out:
#                     name  marks     class  age
# First   Daniyal Basharat     80  1st Year   20
# Second        M Abdullah     72  2nd Year   21
# Third      Muhammad Abid     77  1st Year   19
# Fourth      Shumail Khan     65  3rd Year   22
# Fifth          Qasim Ali     15  2nd Year   21

# %%
type(classData)
# Out:
# pandas.DataFrame

# %%
import numpy as np

# %%
series1= pd.Series(np.random.rand())

# %%
series1
# Out:
# 0    0.874972
# dtype: float64

# %%
series1= pd.Series(np.random.rand(30))

# %%
series1
# Out:
# 0     0.097697
# 1     0.588536
# 2     0.787561
# 3     0.507561
# 4     0.048638
# 5     0.100514
# 6     0.120288
# 7     0.838380
# 8     0.482490
# 9     0.092529
# 10    0.001102
# 11    0.653974
# 12    0.171169
# 13    0.028317
# 14    0.915243
# 15    0.730553
# 16    0.495784
# 17    0.903825
# 18    0.406022
# 19    0.311777
# 20    0.418028
# 21    0.532091
# 22    0.483505
# 23    0.408609
# 24    0.010729
# 25    0.849333
# 26    0.330769
# 27    0.949183
# 28    0.358859
# 29    0.207007
# dtype: float64

# %%
type(series1)
# Out:
# pandas.Series

# %%
np.random.rand(3,4)
# Out:
# array([[0.04184206, 0.05617848, 0.35946073, 0.54999532],
#        [0.29324058, 0.03096376, 0.79745978, 0.65480398],
#        [0.72062732, 0.20695536, 0.79541918, 0.41126812]])

# %%
newDf = pd.DataFrame(np.random.rand(330,5))
# newDf = pd.DataFrame(np.random.rand(330,5), index=np.arange(330))

# %%
type(newDf)
# Out:
# pandas.DataFrame

# %%
newDf.head(2)
# Out:
#           0         1         2         3         4
# 0  0.506347  0.429578  0.436769  0.177261  0.091772
# 1  0.346077  0.673472  0.623099  0.799790  0.862662

# %%
newDf.tail(2)
# Out:
#             0         1         2         3         4
# 328  0.522949  0.129179  0.496525  0.672257  0.614697
# 329  0.486032  0.431836  0.961544  0.758247  0.719259

# %%
newDf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       330 non-null    float64
#  1   1       330 non-null    float64
#  2   2       330 non-null    float64
#  3   3       330 non-null    float64
#  4   4       330 non-null    float64
# dtypes: float64(5)
# memory usage: 13.0 KB

# %%
newDf.describe()
# Out:
#                 0           1           2           3           4
# count  330.000000  330.000000  330.000000  330.000000  330.000000
# mean     0.526999    0.519031    0.483213    0.526818    0.493030
# std      0.291112    0.284067    0.294347    0.283513    0.290378
# min      0.004386    0.012630    0.003135    0.000270    0.002052
# 25%      0.307599    0.272818    0.220858    0.298282    0.222863
# 50%      0.530998    0.530886    0.490763    0.553924    0.494192
# 75%      0.788499    0.765990    0.745811    0.760060    0.748131
# max      0.995911    0.992960    0.999883    0.998392    0.994235

# %%
newDf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %% [markdown]
# # Change the value inside the dataframe

# %%
newDf[0][0]= 10000.0
# Out:
# C:\Users\engin\AppData\Local\Temp\ipykernel_20476\1615845312.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   newDf[0][0]= 10000.0

# %%
newDf
# Out:
#             0         1         2         3         4
# 0    0.506347  0.429578  0.436769  0.177261  0.091772
# 1    0.346077  0.673472  0.623099  0.799790  0.862662
# 2    0.234967  0.246847  0.605068  0.377762  0.165425
# 3    0.873877  0.523773  0.114289  0.205897  0.932115
# 4    0.424802  0.527786  0.026125  0.907716  0.803409
# ..        ...       ...       ...       ...       ...
# 325  0.318888  0.683570  0.225811  0.629169  0.175035
# 326  0.400679  0.943985  0.749789  0.397487  0.875766
# 327  0.991202  0.473211  0.011192  0.421070  0.033817
# 328  0.522949  0.129179  0.496525  0.672257  0.614697
# 329  0.486032  0.431836  0.961544  0.758247  0.719259
#
# [330 rows x 5 columns]

# %%
newDf.head()
# Out:
#           0         1         2         3         4
# 0  0.506347  0.429578  0.436769  0.177261  0.091772
# 1  0.346077  0.673472  0.623099  0.799790  0.862662
# 2  0.234967  0.246847  0.605068  0.377762  0.165425
# 3  0.873877  0.523773  0.114289  0.205897  0.932115
# 4  0.424802  0.527786  0.026125  0.907716  0.803409

# %% [markdown]
# # Transpose

# %%
newDf.T
# Out:
#         0         1         2         3         4         5         6    \
# 0  0